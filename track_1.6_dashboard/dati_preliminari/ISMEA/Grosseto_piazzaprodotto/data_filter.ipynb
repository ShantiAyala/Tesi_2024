# %%
pip install pandas jupyter
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/5.0 MB ? eta -:--:--
#      ----                                     0.6/5.0 MB 12.0 MB/s eta 0:00:01
#      -------------                            1.7/5.0 MB 18.4 MB/s eta 0:00:01
#      --------------------                     2.6/5.0 MB 20.6 MB/s eta 0:00:01
#      ----------------------------             3.6/5.0 MB 19.1 MB/s eta 0:00:01
#      -------------------------------------    4.7/5.0 MB 21.5 MB/s eta 0:00:01
#      ---------------------------------------- 5.0/5.0 MB 18.9 MB/s eta 0:00:00
# ...
#                                               0.0/123.4 kB ? eta -:--:--
#      -------------------------------------- 123.4/123.4 kB 7.1 MB/s eta 0:00:00
# ...
#                                               0.0/257.4 kB ? eta -:--:--
# ...

# %%
import pandas as pd

# Sostituisci 'path_to_your_csv_file.csv' con il percorso del tuo file CSV
df = pd.read_csv('PO_2020.csv')
print(df)
# Out:
#                             DATAFLOW FREQ REF_AREA DATA_TYPE LEGAL_FORM  \
# 0     IT1:102_974_DF_DCSP_SPA_2(1.0)    A       IT       ART        TOT
# 1     IT1:102_974_DF_DCSP_SPA_2(1.0)    A       IT       ART        TOT
# 2     IT1:102_974_DF_DCSP_SPA_2(1.0)    A       IT       ART        TOT
# 3     IT1:102_974_DF_DCSP_SPA_2(1.0)    A       IT       ART        TOT
# 4     IT1:102_974_DF_DCSP_SPA_2(1.0)    A       IT       ART        TOT
# ...                              ...  ...      ...       ...        ...
# 1645  IT1:102_974_DF_DCSP_SPA_2(1.0)    A     ITG2        HO        TOT
# 1646  IT1:102_974_DF_DCSP_SPA_2(1.0)    A     ITG2        HO        TOT
# 1647  IT1:102_974_DF_DCSP_SPA_2(1.0)    A     ITG2        HO        TOT
# 1648  IT1:102_974_DF_DCSP_SPA_2(1.0)    A     ITG2        HO        TOT
# 1649  IT1:102_974_DF_DCSP_SPA_2(1.0)    A     ITG2        HO        TOT
#
#      MANAGEMENT_FORM LAND_OWNERSHIP AGRI_AREA_CLASS TYPE_OF_CROP TYPE_OF_HERD  \
# ...
